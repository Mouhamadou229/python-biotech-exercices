# %%
####a=Application_lecon_chap04
patient = {
    "id": "P001",
    "age": 45,
    "triglycerides": 1.8,
    "hdl": 0.45,
    "syndrome_metabolique": True

}
 
print(patient["age"])          # 45
patient["imc"] = 27.3           # ajouter une nouvelle clé
for cle, valeur in patient.items():
    print(cle, ":", valeur)
# Out:
# 45
# id : P001
# age : 45
# triglycerides : 1.8
# hdl : 0.45
# syndrome_metabolique : True
# imc : 27.3

# %%
###Correction_exo04.1

patients=[
{
    "id": "P001",
    "Age": 28,
    "Triglycérides": 1.7,
    "HDL_C": 0.36
},
{
    "id": "P002",
    "Age": 26,
    "Triglycérides": 1.2,
    "HDL_C": 0.35
},
{
    "id": "P003",
    "Age": 27,
    "Triglycérides": 1.3,
    "HDL_C": 0.39
},
{
    "id": "P004",
    "Age": 25,
    "Triglycérides": 1.2,
    "HDL_C": 0.35
},
{
    "id": "P005",
    "Age": 36,
    "Triglycérides": 1.8,
    "HDL_C": 0.35
}
]   
for patient in patients:
    ratio =round(patient["Triglycérides"]/patient["HDL_C"],2)
    patient["Ratio TG/HDL_C"]= ratio
for patient in patients:
    for cle, valeur in patient.items():
        print(cle,":",valeur)
    print("____________________________")
# Out:
# id : P001
# Age : 28
# Triglycérides : 1.7
# HDL_C : 0.36
# Ratio TG/HDL_C : 4.72
# ____________________________
# id : P002
# Age : 26
# Triglycérides : 1.2
# HDL_C : 0.35
# Ratio TG/HDL_C : 3.43
# ____________________________
# id : P003
# Age : 27
# Triglycérides : 1.3
# HDL_C : 0.39
# Ratio TG/HDL_C : 3.33
# ____________________________
# id : P004
# Age : 25
# Triglycérides : 1.2
# HDL_C : 0.35
# Ratio TG/HDL_C : 3.43
# ____________________________
# id : P005
# Age : 36
# Triglycérides : 1.8
# HDL_C : 0.35
# Ratio TG/HDL_C : 5.14
# ____________________________
